# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/mit-futuremakers-summer-2024-Ftalxx/blob/main/Module_13_Regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Objective
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/'
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])

    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split()
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
    return " ".join(clean_words)

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)

    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }

    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
! mkdir input/
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 199MB/s]
# mkdir: cannot create directory ‘input/’: File exists
# Epoch 1/20
# 24/24 [==============================] - 2s 62ms/step - loss: 0.9075 - accuracy: 0.6073 - val_loss: 0.7346 - val_accuracy: 0.6692
# Epoch 2/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.6437 - accuracy: 0.7310 - val_loss: 0.5749 - val_accuracy: 0.7838
# Epoch 3/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.4868 - accuracy: 0.8263 - val_loss: 0.5165 - val_accuracy: 0.7982
# Epoch 4/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.3978 - accuracy: 0.8602 - val_loss: 0.4991 - val_accuracy: 0.8012
# Epoch 5/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.3354 - accuracy: 0.8819 - val_loss: 0.5031 - val_accuracy: 0.7997
# Epoch 6/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2870 - accuracy: 0.9011 - val_loss: 0.5156 - val_accuracy: 0.7997
# Epoch 7/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.2460 - accuracy: 0.9164 - val_loss: 0.5341 - val_accuracy: 0.7944
# Epoch 8/20
# 24/24 [==============================] - 2s 82ms/step - loss: 0.2128 - accuracy: 0.9282 - val_loss: 0.5554 - val_accuracy: 0.7921
# Epoch 9/20
# 24/24 [==============================] - 2s 68ms/step - loss: 0.1830 - accuracy: 0.9400 - val_loss: 0.5958 - val_accuracy: 0.7845
# Epoch 10/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.1592 - accuracy: 0.9470 - val_loss: 0.6254 - val_accuracy: 0.7891
# Epoch 11/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.1393 - accuracy: 0.9567 - val_loss: 0.6613 - val_accuracy: 0.7891
# Epoch 12/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.1222 - accuracy: 0.9608 - val_loss: 0.6955 - val_accuracy: 0.7792
# Epoch 13/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.1065 - accuracy: 0.9656 - val_loss: 0.7402 - val_accuracy: 0.7830
# Epoch 14/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0946 - accuracy: 0.9705 - val_loss: 0.7798 - val_accuracy: 0.7800
# Epoch 15/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0835 - accuracy: 0.9740 - val_loss: 0.8329 - val_accuracy: 0.7686
# Epoch 16/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0736 - accuracy: 0.9772 - val_loss: 0.8710 - val_accuracy: 0.7754
# Epoch 17/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0654 - accuracy: 0.9793 - val_loss: 0.9252 - val_accuracy: 0.7640
# Epoch 18/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0592 - accuracy: 0.9824 - val_loss: 0.9570 - val_accuracy: 0.7716
# Epoch 19/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0544 - accuracy: 0.9838 - val_loss: 1.0016 - val_accuracy: 0.7739
# Epoch 20/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0494 - accuracy: 0.9855 - val_loss: 1.0487 - val_accuracy: 0.7580
# Minimum validation loss reached in epoch 4
# Epoch 1/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.9926 - accuracy: 0.6309 - val_loss: 0.8904 - val_accuracy: 0.6730
# Epoch 2/20
# 24/24 [==============================] - 1s 27ms/step - loss: 0.8310 - accuracy: 0.6756 - val_loss: 0.7748 - val_accuracy: 0.6980
# Epoch 3/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.7274 - accuracy: 0.7045 - val_loss: 0.6993 - val_accuracy: 0.7185
# Epoch 4/20
# 24/24 [==============================] - 1s 28ms/step - loss: 0.6534 - accuracy: 0.7309 - val_loss: 0.6470 - val_accuracy: 0.7451
# Epoch 5/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.5958 - accuracy: 0.7617 - val_loss: 0.6070 - val_accuracy: 0.7610
# Epoch 6/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.5484 - accuracy: 0.7929 - val_loss: 0.5754 - val_accuracy: 0.7898
# Epoch 7/20
# 24/24 [==============================] - 1s 30ms/step - loss: 0.5088 - accuracy: 0.8209 - val_loss: 0.5510 - val_accuracy: 0.7951
# Epoch 8/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.4758 - accuracy: 0.8377 - val_loss: 0.5325 - val_accuracy: 0.8035
# Epoch 9/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.4474 - accuracy: 0.8490 - val_loss: 0.5193 - val_accuracy: 0.8065
# Epoch 10/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.4225 - accuracy: 0.8597 - val_loss: 0.5082 - val_accuracy: 0.8096
# Epoch 11/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4014 - accuracy: 0.8659 - val_loss: 0.5010 - val_accuracy: 0.8118
# Epoch 12/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.3824 - accuracy: 0.8720 - val_loss: 0.4950 - val_accuracy: 0.8096
# Epoch 13/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.3653 - accuracy: 0.8786 - val_loss: 0.4925 - val_accuracy: 0.8042
# Epoch 14/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.3499 - accuracy: 0.8841 - val_loss: 0.4881 - val_accuracy: 0.8050
# Epoch 15/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.3356 - accuracy: 0.8890 - val_loss: 0.4870 - val_accuracy: 0.8065
# Epoch 16/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.3227 - accuracy: 0.8931 - val_loss: 0.4861 - val_accuracy: 0.8065
# Epoch 17/20
# 24/24 [==============================] - 1s 28ms/step - loss: 0.3105 - accuracy: 0.8963 - val_loss: 0.4865 - val_accuracy: 0.8065
# Epoch 18/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.2992 - accuracy: 0.9006 - val_loss: 0.4882 - val_accuracy: 0.8065
# Epoch 19/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2886 - accuracy: 0.9053 - val_loss: 0.4903 - val_accuracy: 0.8073
# Epoch 20/20
# 24/24 [==============================] - 1s 28ms/step - loss: 0.2787 - accuracy: 0.9076 - val_loss: 0.4930 - val_accuracy: 0.8088
# Minimum validation loss reached in epoch 16

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 64)                640064
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dense_15 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644419 (2.46 MB)
# Trainable params: 644419 (2.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 67ms/step - loss: 1.0563 - accuracy: 0.6170 - val_loss: 0.8860 - val_accuracy: 0.6662
# Epoch 2/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.8086 - accuracy: 0.7133 - val_loss: 0.7426 - val_accuracy: 0.7602
# Epoch 3/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.6608 - accuracy: 0.8029 - val_loss: 0.6587 - val_accuracy: 0.7951
# Epoch 4/20
# 24/24 [==============================] - 2s 87ms/step - loss: 0.5622 - accuracy: 0.8458 - val_loss: 0.6253 - val_accuracy: 0.7951
# Epoch 5/20
# 24/24 [==============================] - 2s 104ms/step - loss: 0.4980 - accuracy: 0.8670 - val_loss: 0.6147 - val_accuracy: 0.8035
# Epoch 6/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.4516 - accuracy: 0.8824 - val_loss: 0.6155 - val_accuracy: 0.8005
# Epoch 7/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.4162 - accuracy: 0.8951 - val_loss: 0.6177 - val_accuracy: 0.8058
# Epoch 8/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.3870 - accuracy: 0.9077 - val_loss: 0.6367 - val_accuracy: 0.7989
# Epoch 9/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3637 - accuracy: 0.9167 - val_loss: 0.6430 - val_accuracy: 0.7997
# Epoch 10/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.3414 - accuracy: 0.9224 - val_loss: 0.6578 - val_accuracy: 0.7974
# Epoch 11/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.3242 - accuracy: 0.9307 - val_loss: 0.6839 - val_accuracy: 0.7860
# Epoch 12/20
# 24/24 [==============================] - 2s 76ms/step - loss: 0.3073 - accuracy: 0.9371 - val_loss: 0.6817 - val_accuracy: 0.7891
# Epoch 13/20
# 24/24 [==============================] - 2s 88ms/step - loss: 0.2950 - accuracy: 0.9421 - val_loss: 0.7148 - val_accuracy: 0.7883
# Epoch 14/20
# 24/24 [==============================] - 2s 102ms/step - loss: 0.2847 - accuracy: 0.9454 - val_loss: 0.7136 - val_accuracy: 0.7838
# Epoch 15/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.2738 - accuracy: 0.9483 - val_loss: 0.7281 - val_accuracy: 0.7822
# Epoch 16/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2640 - accuracy: 0.9544 - val_loss: 0.7331 - val_accuracy: 0.7807
# Epoch 17/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2547 - accuracy: 0.9555 - val_loss: 0.7544 - val_accuracy: 0.7845
# Epoch 18/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.2465 - accuracy: 0.9604 - val_loss: 0.7575 - val_accuracy: 0.7868
# Epoch 19/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.2412 - accuracy: 0.9602 - val_loss: 0.7683 - val_accuracy: 0.7762
# Epoch 20/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.2318 - accuracy: 0.9630 - val_loss: 0.7896 - val_accuracy: 0.7709
# Minimum validation loss reached in epoch 5

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    reg = sum(abs(w) for w in weights)
    return reg

print(l1_norm(weights))
# Out:
# 15

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    reg = sum(w**2 for w in weights)
    return reg

print(l2_norm(weights))
# Out:
# 55

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_17 (Dense)            (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_18 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644419 (2.46 MB)
# Trainable params: 644419 (2.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 3s 84ms/step - loss: 0.9172 - accuracy: 0.6009 - val_loss: 0.7605 - val_accuracy: 0.6335
# Epoch 2/20
# 24/24 [==============================] - 2s 102ms/step - loss: 0.7389 - accuracy: 0.6390 - val_loss: 0.6732 - val_accuracy: 0.6806
# Epoch 3/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.6429 - accuracy: 0.7188 - val_loss: 0.5999 - val_accuracy: 0.7785
# Epoch 4/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.5600 - accuracy: 0.7929 - val_loss: 0.5594 - val_accuracy: 0.7898
# Epoch 5/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.4975 - accuracy: 0.8183 - val_loss: 0.5197 - val_accuracy: 0.8035
# Epoch 6/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.4422 - accuracy: 0.8448 - val_loss: 0.5069 - val_accuracy: 0.8058
# Epoch 7/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.4096 - accuracy: 0.8569 - val_loss: 0.5101 - val_accuracy: 0.8073
# Epoch 8/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3751 - accuracy: 0.8706 - val_loss: 0.5095 - val_accuracy: 0.8080
# Epoch 9/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.3422 - accuracy: 0.8793 - val_loss: 0.5197 - val_accuracy: 0.8058
# Epoch 10/20
# 24/24 [==============================] - 2s 76ms/step - loss: 0.3170 - accuracy: 0.8890 - val_loss: 0.5248 - val_accuracy: 0.8042
# Epoch 11/20
# 24/24 [==============================] - 4s 156ms/step - loss: 0.2885 - accuracy: 0.8999 - val_loss: 0.5489 - val_accuracy: 0.7997
# Epoch 12/20
# 24/24 [==============================] - 3s 120ms/step - loss: 0.2733 - accuracy: 0.9060 - val_loss: 0.5515 - val_accuracy: 0.8042
# Epoch 13/20
# 24/24 [==============================] - 2s 95ms/step - loss: 0.2510 - accuracy: 0.9130 - val_loss: 0.5699 - val_accuracy: 0.8005
# Epoch 14/20
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2348 - accuracy: 0.9222 - val_loss: 0.5959 - val_accuracy: 0.8012
# Epoch 15/20
# 24/24 [==============================] - 2s 97ms/step - loss: 0.2154 - accuracy: 0.9286 - val_loss: 0.6138 - val_accuracy: 0.7997
# Epoch 16/20
# 24/24 [==============================] - 3s 117ms/step - loss: 0.2082 - accuracy: 0.9304 - val_loss: 0.6271 - val_accuracy: 0.7944
# Epoch 17/20
# 24/24 [==============================] - 3s 134ms/step - loss: 0.1910 - accuracy: 0.9356 - val_loss: 0.6551 - val_accuracy: 0.7967
# Epoch 18/20
# 24/24 [==============================] - 3s 115ms/step - loss: 0.1787 - accuracy: 0.9414 - val_loss: 0.6747 - val_accuracy: 0.7989
# Epoch 19/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.1625 - accuracy: 0.9479 - val_loss: 0.6950 - val_accuracy: 0.7982
# Epoch 20/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.1533 - accuracy: 0.9512 - val_loss: 0.7180 - val_accuracy: 0.7967
# Minimum validation loss reached in epoch 6

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 11s 401ms/step - loss: nan - accuracy: 0.6163 - val_loss: nan - val_accuracy: 0.6335
# Epoch 2/20
# 24/24 [==============================] - 7s 303ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 3/20
# 24/24 [==============================] - 9s 376ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 4/20
# 24/24 [==============================] - 10s 424ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 5/20
# 24/24 [==============================] - 8s 319ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 6/20
# 24/24 [==============================] - 9s 386ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 7/20
# 24/24 [==============================] - 7s 312ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 8/20
# 24/24 [==============================] - 9s 386ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 9/20
# 24/24 [==============================] - 7s 308ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 10/20
# 24/24 [==============================] - 11s 456ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 11/20
# 24/24 [==============================] - 10s 400ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 12/20
# 24/24 [==============================] - 7s 300ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 13/20
# 24/24 [==============================] - 9s 393ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 14/20
# 24/24 [==============================] - 8s 330ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 15/20
# 24/24 [==============================] - 9s 383ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 16/20
# 24/24 [==============================] - 8s 356ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 17/20
# 24/24 [==============================] - 8s 320ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 18/20
# 24/24 [==============================] - 9s 371ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 19/20
# 24/24 [==============================] - 7s 308ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Epoch 20/20
# 24/24 [==============================] - 9s 387ms/step - loss: nan - accuracy: 0.6270 - val_loss: nan - val_accuracy: 0.6335
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# I would add both L2 regularization and Dropout to improve my model's generalization and prevent overfitting. L2 regularization keeps the weights smaller, and Dropout makes the model rely on more general features. Using both together makes my model more stable.

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/4
# 26/26 [==============================] - 1s 54ms/step - loss: 0.1423 - accuracy: 0.9643
# Epoch 2/4
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0990 - accuracy: 0.9728
# Epoch 3/4
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0790 - accuracy: 0.9777
# Epoch 4/4
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0641 - accuracy: 0.9818
# 46/46 [==============================] - 0s 6ms/step - loss: 1.0367 - accuracy: 0.7609
#
# Test accuracy: 76.09%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/16
# 26/26 [==============================] - 1s 42ms/step - loss: 0.2916 - accuracy: 0.9001
# Epoch 2/16
# 26/26 [==============================] - 1s 37ms/step - loss: 0.2808 - accuracy: 0.9033
# Epoch 3/16
# 26/26 [==============================] - 1s 28ms/step - loss: 0.2712 - accuracy: 0.9073
# Epoch 4/16
# 26/26 [==============================] - 1s 25ms/step - loss: 0.2621 - accuracy: 0.9123
# Epoch 5/16
# 26/26 [==============================] - 1s 26ms/step - loss: 0.2533 - accuracy: 0.9158
# Epoch 6/16
# 26/26 [==============================] - 1s 28ms/step - loss: 0.2452 - accuracy: 0.9177
# Epoch 7/16
# 26/26 [==============================] - 1s 26ms/step - loss: 0.2374 - accuracy: 0.9216
# Epoch 8/16
# 26/26 [==============================] - 1s 26ms/step - loss: 0.2298 - accuracy: 0.9230
# Epoch 9/16
# 26/26 [==============================] - 1s 26ms/step - loss: 0.2231 - accuracy: 0.9248
# Epoch 10/16
# 26/26 [==============================] - 1s 27ms/step - loss: 0.2164 - accuracy: 0.9273
# Epoch 11/16
# 26/26 [==============================] - 1s 26ms/step - loss: 0.2100 - accuracy: 0.9296
# Epoch 12/16
# 26/26 [==============================] - 1s 28ms/step - loss: 0.2038 - accuracy: 0.9327
# Epoch 13/16
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1979 - accuracy: 0.9347
# Epoch 14/16
# 26/26 [==============================] - 1s 25ms/step - loss: 0.1923 - accuracy: 0.9368
# Epoch 15/16
# 26/26 [==============================] - 1s 27ms/step - loss: 0.1868 - accuracy: 0.9394
# Epoch 16/16
# 26/26 [==============================] - 1s 25ms/step - loss: 0.1817 - accuracy: 0.9419
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.7760
#
# Test accuracy: 77.60%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 2s 86ms/step - loss: 0.2845 - accuracy: 0.9463
# Epoch 2/5
# 26/26 [==============================] - 2s 69ms/step - loss: 0.2566 - accuracy: 0.9537
# Epoch 3/5
# 26/26 [==============================] - 1s 49ms/step - loss: 0.2412 - accuracy: 0.9592
# Epoch 4/5
# 26/26 [==============================] - 1s 48ms/step - loss: 0.2335 - accuracy: 0.9612
# Epoch 5/5
# 26/26 [==============================] - 1s 49ms/step - loss: 0.2234 - accuracy: 0.9649
# 46/46 [==============================] - 0s 4ms/step - loss: 0.8210 - accuracy: 0.7616
#
# Test accuracy: 76.16%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/6
# 26/26 [==============================] - 2s 58ms/step - loss: 0.2060 - accuracy: 0.9372
# Epoch 2/6
# 26/26 [==============================] - 2s 80ms/step - loss: 0.1897 - accuracy: 0.9419
# Epoch 3/6
# 26/26 [==============================] - 2s 86ms/step - loss: 0.1755 - accuracy: 0.9438
# Epoch 4/6
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1570 - accuracy: 0.9505
# Epoch 5/6
# 26/26 [==============================] - 1s 52ms/step - loss: 0.1476 - accuracy: 0.9528
# Epoch 6/6
# 26/26 [==============================] - 1s 49ms/step - loss: 0.1405 - accuracy: 0.9554
# 46/46 [==============================] - 0s 4ms/step - loss: 0.7930 - accuracy: 0.7766
#
# Test accuracy: 77.66%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 1
#
# Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: 0.5 * np.mean((w[0] + w[1] * x - y) ** 2)
l1_penalty = lambda w: np.sum(np.abs(w))
cost_plus_l1 = lambda w: cost(w) + 5 * l1_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# L1 makes weights smaller and sparse, picking important features. L2 keeps weights from getting too large, making the model stable. Both help prevent overfitting and improve training.

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md
